# %%
#load library
import pandas as pd
import numpy as np
import csv
from nltk.corpus import stopwords
import nltk as nltk
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from textblob import TextBlob

# %%
#membaca file csv
# train Data
bacaData= pd.read_csv(open('DATA_TES2.csv', newline='', encoding='utf-8'), delimiter=';')
trainData = pd.DataFrame(bacaData) 
# test Data
testData = pd.read_csv(open('Sentiment_Type.csv', newline='', encoding='utf-8'), delimiter=';')

# %%
#menampilkan dari fle csv
print (trainData.shape)
trainData.head(10)
# Out:
# (15, 6)
#    no        username                      name  \
# 0   1  kojekrapbetawi         Muhammad Amrullah
# 1   2    benar_berita       BenarNews Indonesia
# 2   3      suprabacot               scutellaria
# 3   4    lestarisarmi             Sarmi Lestari
# 4   5    bawaslujatim             Bawaslu Jatim
# 5   6   masjidrayakbm               MASJID RAYA
# 6   7  balanekangjuki  WongKebumenBisaNgapaBaen
# 7   8   penyebarkabar                Korban PHP
# 8   9         ini_net           ini.kebumen.net
# 9  10          nasdem             Partai NasDem
#
#                                                tweet language Lebel
# 0  Selamat pagi Indonesia #pilkadacovid  https://...       in   POS
# 1  Hasil Hitung Cepat: Anak dan Menantu Jokowi Me...       in   POS
# 2  permisi... nitip dong ???? #fyp #pilkadaserent...       in   POS
# 3  pilkada2020 #pilkadacovid #pilkadamaut  Data p...       in   POS
# 4  Evaluasi Media Sosial Bawaslu Jatim, Youtube P...       in   POS
# 5  Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 6  #masukpakeko  Gus Yazid Ajak Masyarakat Dukung...       in   POS
# 7  #Mmmh  Gus Yazid Ajak Masyarakat Dukung Bupati...       in   POS
# 8  Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 9  DPP Partai NasDem juga menunjuk Kakak Hermawi ...       in   NEG

# %% [markdown]
# PROSES PREPRCESSING

# %%
#update data stopwords
stopset = set(stopwords.words('indonesian'))
stopset.update(['kirim','kabar','lindung','pilkadacovid','bawaslukotadepokkawalpilkada'])

# %%
import re
def clean_tweets(row):
    review = row['tweet']
    drop = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", review).split())
    return drop
trainData['clean_tweets'] = trainData.apply(clean_tweets, axis=1)

# %%
trainData
# Out:
#     no         username                      name  \
# 0    1   kojekrapbetawi         Muhammad Amrullah
# 1    2     benar_berita       BenarNews Indonesia
# 2    3       suprabacot               scutellaria
# 3    4     lestarisarmi             Sarmi Lestari
# 4    5     bawaslujatim             Bawaslu Jatim
# 5    6    masjidrayakbm               MASJID RAYA
# 6    7   balanekangjuki  WongKebumenBisaNgapaBaen
# 7    8    penyebarkabar                Korban PHP
# 8    9          ini_net           ini.kebumen.net
# 9   10           nasdem             Partai NasDem
# 10  11   kaltimofficial           Kaltim Official
# 11  12  seputarinfoindo    Seputar Info Indonesia
# 12  13  seputarinfoindo    Seputar Info Indonesia
# 13  14   marjenrokcalva                  Rokcalva
# 14  15    bawasludepok_        Bawaslu Kota Depok
#
#                                                 tweet language Lebel  \
# 0   Selamat pagi Indonesia #pilkadacovid  https://...       in   POS
# 1   Hasil Hitung Cepat: Anak dan Menantu Jokowi Me...       in   POS
# 2   permisi... nitip dong ???? #fyp #pilkadaserent...       in   POS
# 3   pilkada2020 #pilkadacovid #pilkadamaut  Data p...       in   POS
# 4   Evaluasi Media Sosial Bawaslu Jatim, Youtube P...       in   POS
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 6   #masukpakeko  Gus Yazid Ajak Masyarakat Dukung...       in   POS
# 7   #Mmmh  Gus Yazid Ajak Masyarakat Dukung Bupati...       in   POS
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...       in   NEG
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...       in   NEG
# 11  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 12  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 13  @KEMENPORA_RI Buka Peluang Sumbar Jadi Tuan Ru...       in   NEG
# 14  Halo #SahabatBawaslu. Depok (30 Desember 2020)...       in   NEG
#
#                                          clean_tweets
# 0                 Selamat pagi Indonesia pilkadacovid
# 1   Hasil Hitung Cepat Anak dan Menantu Jokowi Men...
# 2   permisi nitip dong fyp pilkadaserentak2020 PIL...
# 3   pilkada2020 pilkadacovid pilkadamaut Data per ...
# 4   Evaluasi Media Sosial Bawaslu Jatim Youtube Pa...
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 6   masukpakeko Gus Yazid Ajak Masyarakat Dukung B...
# 7   Mmmh Gus Yazid Ajak Masyarakat Dukung Bupati d...
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...
# 11  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 12  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 13  RI Buka Peluang Sumbar Jadi Tuan Rumah JPI Tah...
# 14  Halo SahabatBawaslu Depok 30 Desember 2020 Baw...

# %%
#proses tokenizng
def identify_tokens(row):
    review = row['clean_tweets']
    tokens = nltk.word_tokenize(review)
    # taken only words (not punctuation)
    token_words = [w for w in tokens]
    return token_words

trainData['tokenizing_word'] = trainData.apply(identify_tokens, axis=1)

# %%
trainData
# Out:
#     no         username                      name  \
# 0    1   kojekrapbetawi         Muhammad Amrullah
# 1    2     benar_berita       BenarNews Indonesia
# 2    3       suprabacot               scutellaria
# 3    4     lestarisarmi             Sarmi Lestari
# 4    5     bawaslujatim             Bawaslu Jatim
# 5    6    masjidrayakbm               MASJID RAYA
# 6    7   balanekangjuki  WongKebumenBisaNgapaBaen
# 7    8    penyebarkabar                Korban PHP
# 8    9          ini_net           ini.kebumen.net
# 9   10           nasdem             Partai NasDem
# 10  11   kaltimofficial           Kaltim Official
# 11  12  seputarinfoindo    Seputar Info Indonesia
# 12  13  seputarinfoindo    Seputar Info Indonesia
# 13  14   marjenrokcalva                  Rokcalva
# 14  15    bawasludepok_        Bawaslu Kota Depok
#
#                                                 tweet language Lebel  \
# 0   Selamat pagi Indonesia #pilkadacovid  https://...       in   POS
# 1   Hasil Hitung Cepat: Anak dan Menantu Jokowi Me...       in   POS
# 2   permisi... nitip dong ???? #fyp #pilkadaserent...       in   POS
# 3   pilkada2020 #pilkadacovid #pilkadamaut  Data p...       in   POS
# 4   Evaluasi Media Sosial Bawaslu Jatim, Youtube P...       in   POS
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 6   #masukpakeko  Gus Yazid Ajak Masyarakat Dukung...       in   POS
# 7   #Mmmh  Gus Yazid Ajak Masyarakat Dukung Bupati...       in   POS
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...       in   NEG
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...       in   NEG
# 11  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 12  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 13  @KEMENPORA_RI Buka Peluang Sumbar Jadi Tuan Ru...       in   NEG
# 14  Halo #SahabatBawaslu. Depok (30 Desember 2020)...       in   NEG
#
#                                          clean_tweets  \
# 0                 Selamat pagi Indonesia pilkadacovid
# 1   Hasil Hitung Cepat Anak dan Menantu Jokowi Men...
# 2   permisi nitip dong fyp pilkadaserentak2020 PIL...
# 3   pilkada2020 pilkadacovid pilkadamaut Data per ...
# 4   Evaluasi Media Sosial Bawaslu Jatim Youtube Pa...
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 6   masukpakeko Gus Yazid Ajak Masyarakat Dukung B...
# 7   Mmmh Gus Yazid Ajak Masyarakat Dukung Bupati d...
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...
# 11  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 12  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 13  RI Buka Peluang Sumbar Jadi Tuan Rumah JPI Tah...
# 14  Halo SahabatBawaslu Depok 30 Desember 2020 Baw...
#
#                                       tokenizing_word
# 0            [Selamat, pagi, Indonesia, pilkadacovid]
# 1   [Hasil, Hitung, Cepat, Anak, dan, Menantu, Jok...
# 2   [permisi, nitip, dong, fyp, pilkadaserentak202...
# 3   [pilkada2020, pilkadacovid, pilkadamaut, Data,...
# 4   [Evaluasi, Media, Sosial, Bawaslu, Jatim, Yout...
# 5   [Gus, Yazid, Ajak, Masyarakat, Dukung, Bupati,...
# 6   [masukpakeko, Gus, Yazid, Ajak, Masyarakat, Du...
# 7   [Mmmh, Gus, Yazid, Ajak, Masyarakat, Dukung, B...
# 8   [Gus, Yazid, Ajak, Masyarakat, Dukung, Bupati,...
# 9   [DPP, Partai, NasDem, juga, menunjuk, Kakak, H...
# 10  [Bukti, kesuksessan, pemerintah, menyelenggara...
# 11  [Pilkada, 2020, Berjalan, Aman, Lancar, dan, T...
# 12  [Pilkada, 2020, Berjalan, Aman, Lancar, dan, T...
# 13  [RI, Buka, Peluang, Sumbar, Jadi, Tuan, Rumah,...
# 14  [Halo, SahabatBawaslu, Depok, 30, Desember, 20...

# %%
#proses stemming
def stem_list(row):
    my_list = row['tokenizing_word']
    stemmed_list = [stemmer.stem(word) for word in my_list]
    return (stemmed_list)

trainData['stemming_word'] = trainData.apply(stem_list, axis=1)

# %%
trainData
# Out:
#     no         username                      name  \
# 0    1   kojekrapbetawi         Muhammad Amrullah
# 1    2     benar_berita       BenarNews Indonesia
# 2    3       suprabacot               scutellaria
# 3    4     lestarisarmi             Sarmi Lestari
# 4    5     bawaslujatim             Bawaslu Jatim
# 5    6    masjidrayakbm               MASJID RAYA
# 6    7   balanekangjuki  WongKebumenBisaNgapaBaen
# 7    8    penyebarkabar                Korban PHP
# 8    9          ini_net           ini.kebumen.net
# 9   10           nasdem             Partai NasDem
# 10  11   kaltimofficial           Kaltim Official
# 11  12  seputarinfoindo    Seputar Info Indonesia
# 12  13  seputarinfoindo    Seputar Info Indonesia
# 13  14   marjenrokcalva                  Rokcalva
# 14  15    bawasludepok_        Bawaslu Kota Depok
#
#                                                 tweet language Lebel  \
# 0   Selamat pagi Indonesia #pilkadacovid  https://...       in   POS
# 1   Hasil Hitung Cepat: Anak dan Menantu Jokowi Me...       in   POS
# 2   permisi... nitip dong ???? #fyp #pilkadaserent...       in   POS
# 3   pilkada2020 #pilkadacovid #pilkadamaut  Data p...       in   POS
# 4   Evaluasi Media Sosial Bawaslu Jatim, Youtube P...       in   POS
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 6   #masukpakeko  Gus Yazid Ajak Masyarakat Dukung...       in   POS
# 7   #Mmmh  Gus Yazid Ajak Masyarakat Dukung Bupati...       in   POS
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...       in   NEG
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...       in   NEG
# 11  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 12  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 13  @KEMENPORA_RI Buka Peluang Sumbar Jadi Tuan Ru...       in   NEG
# 14  Halo #SahabatBawaslu. Depok (30 Desember 2020)...       in   NEG
#
#                                          clean_tweets  \
# 0                 Selamat pagi Indonesia pilkadacovid
# 1   Hasil Hitung Cepat Anak dan Menantu Jokowi Men...
# 2   permisi nitip dong fyp pilkadaserentak2020 PIL...
# 3   pilkada2020 pilkadacovid pilkadamaut Data per ...
# 4   Evaluasi Media Sosial Bawaslu Jatim Youtube Pa...
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 6   masukpakeko Gus Yazid Ajak Masyarakat Dukung B...
# 7   Mmmh Gus Yazid Ajak Masyarakat Dukung Bupati d...
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...
# 11  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 12  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 13  RI Buka Peluang Sumbar Jadi Tuan Rumah JPI Tah...
# 14  Halo SahabatBawaslu Depok 30 Desember 2020 Baw...
#
#                                       tokenizing_word  \
# 0            [Selamat, pagi, Indonesia, pilkadacovid]
# 1   [Hasil, Hitung, Cepat, Anak, dan, Menantu, Jok...
# 2   [permisi, nitip, dong, fyp, pilkadaserentak202...
# 3   [pilkada2020, pilkadacovid, pilkadamaut, Data,...
# 4   [Evaluasi, Media, Sosial, Bawaslu, Jatim, Yout...
# 5   [Gus, Yazid, Ajak, Masyarakat, Dukung, Bupati,...
# 6   [masukpakeko, Gus, Yazid, Ajak, Masyarakat, Du...
# 7   [Mmmh, Gus, Yazid, Ajak, Masyarakat, Dukung, B...
# 8   [Gus, Yazid, Ajak, Masyarakat, Dukung, Bupati,...
# 9   [DPP, Partai, NasDem, juga, menunjuk, Kakak, H...
# 10  [Bukti, kesuksessan, pemerintah, menyelenggara...
# 11  [Pilkada, 2020, Berjalan, Aman, Lancar, dan, T...
# 12  [Pilkada, 2020, Berjalan, Aman, Lancar, dan, T...
# 13  [RI, Buka, Peluang, Sumbar, Jadi, Tuan, Rumah,...
# 14  [Halo, SahabatBawaslu, Depok, 30, Desember, 20...
#
#                                         stemming_word
# 0            [selamat, pagi, indonesia, pilkadacovid]
# 1   [hasil, hitung, cepat, anak, dan, menantu, jok...
# 2   [permisi, nitip, dong, fyp, pilkadaserentak202...
# 3   [pilkada2020, pilkadacovid, pilkadamaut, data,...
# 4   [evaluasi, media, sosial, bawaslu, jatim, yout...
# 5   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 6   [masukpakeko, gus, yazid, ajak, masyarakat, du...
# 7   [mmmh, gus, yazid, ajak, masyarakat, dukung, b...
# 8   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 9   [dpp, partai, nasdem, juga, tunjuk, kakak, her...
# 10  [bukti, kesuksessan, perintah, selenggara, pil...
# 11  [pilkada, 2020, jalan, aman, lancar, dan, tert...
# 12  [pilkada, 2020, jalan, aman, lancar, dan, tert...
# 13  [ri, buka, peluang, sumbar, jadi, tuan, rumah,...
# 14  [halo, sahabatbawaslu, depok, 30, desember, 20...

# %%
#proses Alpha
def is_alpha(row):
    my_alpha = row['stemming_word']
    is_alpha = [word for word in my_alpha if word.isalpha()]
    return (is_alpha)

trainData['panctuaton_word'] = trainData.apply(is_alpha, axis=1)

# %%
trainData
# Out:
#     no         username                      name  \
# 0    1   kojekrapbetawi         Muhammad Amrullah
# 1    2     benar_berita       BenarNews Indonesia
# 2    3       suprabacot               scutellaria
# 3    4     lestarisarmi             Sarmi Lestari
# 4    5     bawaslujatim             Bawaslu Jatim
# 5    6    masjidrayakbm               MASJID RAYA
# 6    7   balanekangjuki  WongKebumenBisaNgapaBaen
# 7    8    penyebarkabar                Korban PHP
# 8    9          ini_net           ini.kebumen.net
# 9   10           nasdem             Partai NasDem
# 10  11   kaltimofficial           Kaltim Official
# 11  12  seputarinfoindo    Seputar Info Indonesia
# 12  13  seputarinfoindo    Seputar Info Indonesia
# 13  14   marjenrokcalva                  Rokcalva
# 14  15    bawasludepok_        Bawaslu Kota Depok
#
#                                                 tweet language Lebel  \
# 0   Selamat pagi Indonesia #pilkadacovid  https://...       in   POS
# 1   Hasil Hitung Cepat: Anak dan Menantu Jokowi Me...       in   POS
# 2   permisi... nitip dong ???? #fyp #pilkadaserent...       in   POS
# 3   pilkada2020 #pilkadacovid #pilkadamaut  Data p...       in   POS
# 4   Evaluasi Media Sosial Bawaslu Jatim, Youtube P...       in   POS
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 6   #masukpakeko  Gus Yazid Ajak Masyarakat Dukung...       in   POS
# 7   #Mmmh  Gus Yazid Ajak Masyarakat Dukung Bupati...       in   POS
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...       in   NEG
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...       in   NEG
# 11  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 12  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 13  @KEMENPORA_RI Buka Peluang Sumbar Jadi Tuan Ru...       in   NEG
# 14  Halo #SahabatBawaslu. Depok (30 Desember 2020)...       in   NEG
#
#                                          clean_tweets  \
# 0                 Selamat pagi Indonesia pilkadacovid
# 1   Hasil Hitung Cepat Anak dan Menantu Jokowi Men...
# 2   permisi nitip dong fyp pilkadaserentak2020 PIL...
# 3   pilkada2020 pilkadacovid pilkadamaut Data per ...
# 4   Evaluasi Media Sosial Bawaslu Jatim Youtube Pa...
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 6   masukpakeko Gus Yazid Ajak Masyarakat Dukung B...
# 7   Mmmh Gus Yazid Ajak Masyarakat Dukung Bupati d...
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...
# 11  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 12  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 13  RI Buka Peluang Sumbar Jadi Tuan Rumah JPI Tah...
# 14  Halo SahabatBawaslu Depok 30 Desember 2020 Baw...
#
#                                       tokenizing_word  \
# 0            [Selamat, pagi, Indonesia, pilkadacovid]
# 1   [Hasil, Hitung, Cepat, Anak, dan, Menantu, Jok...
# 2   [permisi, nitip, dong, fyp, pilkadaserentak202...
# 3   [pilkada2020, pilkadacovid, pilkadamaut, Data,...
# 4   [Evaluasi, Media, Sosial, Bawaslu, Jatim, Yout...
# 5   [Gus, Yazid, Ajak, Masyarakat, Dukung, Bupati,...
# 6   [masukpakeko, Gus, Yazid, Ajak, Masyarakat, Du...
# 7   [Mmmh, Gus, Yazid, Ajak, Masyarakat, Dukung, B...
# 8   [Gus, Yazid, Ajak, Masyarakat, Dukung, Bupati,...
# 9   [DPP, Partai, NasDem, juga, menunjuk, Kakak, H...
# 10  [Bukti, kesuksessan, pemerintah, menyelenggara...
# 11  [Pilkada, 2020, Berjalan, Aman, Lancar, dan, T...
# 12  [Pilkada, 2020, Berjalan, Aman, Lancar, dan, T...
# 13  [RI, Buka, Peluang, Sumbar, Jadi, Tuan, Rumah,...
# 14  [Halo, SahabatBawaslu, Depok, 30, Desember, 20...
#
#                                         stemming_word  \
# 0            [selamat, pagi, indonesia, pilkadacovid]
# 1   [hasil, hitung, cepat, anak, dan, menantu, jok...
# 2   [permisi, nitip, dong, fyp, pilkadaserentak202...
# 3   [pilkada2020, pilkadacovid, pilkadamaut, data,...
# 4   [evaluasi, media, sosial, bawaslu, jatim, yout...
# 5   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 6   [masukpakeko, gus, yazid, ajak, masyarakat, du...
# 7   [mmmh, gus, yazid, ajak, masyarakat, dukung, b...
# 8   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 9   [dpp, partai, nasdem, juga, tunjuk, kakak, her...
# 10  [bukti, kesuksessan, perintah, selenggara, pil...
# 11  [pilkada, 2020, jalan, aman, lancar, dan, tert...
# 12  [pilkada, 2020, jalan, aman, lancar, dan, tert...
# 13  [ri, buka, peluang, sumbar, jadi, tuan, rumah,...
# 14  [halo, sahabatbawaslu, depok, 30, desember, 20...
#
#                                       panctuaton_word
# 0            [selamat, pagi, indonesia, pilkadacovid]
# 1   [hasil, hitung, cepat, anak, dan, menantu, jok...
# 2   [permisi, nitip, dong, fyp, republiksulap, pil...
# 3   [pilkadacovid, pilkadamaut, data, per, dapat, ...
# 4   [evaluasi, media, sosial, bawaslu, jatim, yout...
# 5   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 6   [masukpakeko, gus, yazid, ajak, masyarakat, du...
# 7   [mmmh, gus, yazid, ajak, masyarakat, dukung, b...
# 8   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 9   [dpp, partai, nasdem, juga, tunjuk, kakak, her...
# 10  [bukti, kesuksessan, perintah, selenggara, pil...
# 11  [pilkada, jalan, aman, lancar, dan, tertib, pi...
# 12  [pilkada, jalan, aman, lancar, dan, tertib, pi...
# 13  [ri, buka, peluang, sumbar, jadi, tuan, rumah,...
# 14  [halo, sahabatbawaslu, depok, desember, bawasl...

# %%
#proses stopwords
def remove_stops(row):
    my_list = row['panctuaton_word']
    meaningful_words = [w for w in my_list if not w in stopset]
    return (meaningful_words)

trainData['stopword_word'] = trainData.apply(remove_stops, axis=1)

# %%
trainData
# Out:
#     no         username                      name  \
# 0    1   kojekrapbetawi         Muhammad Amrullah
# 1    2     benar_berita       BenarNews Indonesia
# 2    3       suprabacot               scutellaria
# 3    4     lestarisarmi             Sarmi Lestari
# 4    5     bawaslujatim             Bawaslu Jatim
# 5    6    masjidrayakbm               MASJID RAYA
# 6    7   balanekangjuki  WongKebumenBisaNgapaBaen
# 7    8    penyebarkabar                Korban PHP
# 8    9          ini_net           ini.kebumen.net
# 9   10           nasdem             Partai NasDem
# 10  11   kaltimofficial           Kaltim Official
# 11  12  seputarinfoindo    Seputar Info Indonesia
# 12  13  seputarinfoindo    Seputar Info Indonesia
# 13  14   marjenrokcalva                  Rokcalva
# 14  15    bawasludepok_        Bawaslu Kota Depok
#
#                                                 tweet language Lebel  \
# 0   Selamat pagi Indonesia #pilkadacovid  https://...       in   POS
# 1   Hasil Hitung Cepat: Anak dan Menantu Jokowi Me...       in   POS
# 2   permisi... nitip dong ???? #fyp #pilkadaserent...       in   POS
# 3   pilkada2020 #pilkadacovid #pilkadamaut  Data p...       in   POS
# 4   Evaluasi Media Sosial Bawaslu Jatim, Youtube P...       in   POS
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 6   #masukpakeko  Gus Yazid Ajak Masyarakat Dukung...       in   POS
# 7   #Mmmh  Gus Yazid Ajak Masyarakat Dukung Bupati...       in   POS
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...       in   NEG
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...       in   NEG
# 11  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 12  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 13  @KEMENPORA_RI Buka Peluang Sumbar Jadi Tuan Ru...       in   NEG
# 14  Halo #SahabatBawaslu. Depok (30 Desember 2020)...       in   NEG
#
#                                          clean_tweets  \
# 0                 Selamat pagi Indonesia pilkadacovid
# 1   Hasil Hitung Cepat Anak dan Menantu Jokowi Men...
# 2   permisi nitip dong fyp pilkadaserentak2020 PIL...
# 3   pilkada2020 pilkadacovid pilkadamaut Data per ...
# 4   Evaluasi Media Sosial Bawaslu Jatim Youtube Pa...
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 6   masukpakeko Gus Yazid Ajak Masyarakat Dukung B...
# 7   Mmmh Gus Yazid Ajak Masyarakat Dukung Bupati d...
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...
# 11  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 12  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 13  RI Buka Peluang Sumbar Jadi Tuan Rumah JPI Tah...
# 14  Halo SahabatBawaslu Depok 30 Desember 2020 Baw...
#
#                                       tokenizing_word  \
# 0            [Selamat, pagi, Indonesia, pilkadacovid]
# 1   [Hasil, Hitung, Cepat, Anak, dan, Menantu, Jok...
# 2   [permisi, nitip, dong, fyp, pilkadaserentak202...
# 3   [pilkada2020, pilkadacovid, pilkadamaut, Data,...
# 4   [Evaluasi, Media, Sosial, Bawaslu, Jatim, Yout...
# 5   [Gus, Yazid, Ajak, Masyarakat, Dukung, Bupati,...
# 6   [masukpakeko, Gus, Yazid, Ajak, Masyarakat, Du...
# 7   [Mmmh, Gus, Yazid, Ajak, Masyarakat, Dukung, B...
# 8   [Gus, Yazid, Ajak, Masyarakat, Dukung, Bupati,...
# 9   [DPP, Partai, NasDem, juga, menunjuk, Kakak, H...
# 10  [Bukti, kesuksessan, pemerintah, menyelenggara...
# 11  [Pilkada, 2020, Berjalan, Aman, Lancar, dan, T...
# 12  [Pilkada, 2020, Berjalan, Aman, Lancar, dan, T...
# 13  [RI, Buka, Peluang, Sumbar, Jadi, Tuan, Rumah,...
# 14  [Halo, SahabatBawaslu, Depok, 30, Desember, 20...
#
#                                         stemming_word  \
# 0            [selamat, pagi, indonesia, pilkadacovid]
# 1   [hasil, hitung, cepat, anak, dan, menantu, jok...
# 2   [permisi, nitip, dong, fyp, pilkadaserentak202...
# 3   [pilkada2020, pilkadacovid, pilkadamaut, data,...
# 4   [evaluasi, media, sosial, bawaslu, jatim, yout...
# 5   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 6   [masukpakeko, gus, yazid, ajak, masyarakat, du...
# 7   [mmmh, gus, yazid, ajak, masyarakat, dukung, b...
# 8   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 9   [dpp, partai, nasdem, juga, tunjuk, kakak, her...
# 10  [bukti, kesuksessan, perintah, selenggara, pil...
# 11  [pilkada, 2020, jalan, aman, lancar, dan, tert...
# 12  [pilkada, 2020, jalan, aman, lancar, dan, tert...
# 13  [ri, buka, peluang, sumbar, jadi, tuan, rumah,...
# 14  [halo, sahabatbawaslu, depok, 30, desember, 20...
#
#                                       panctuaton_word  \
# 0            [selamat, pagi, indonesia, pilkadacovid]
# 1   [hasil, hitung, cepat, anak, dan, menantu, jok...
# 2   [permisi, nitip, dong, fyp, republiksulap, pil...
# 3   [pilkadacovid, pilkadamaut, data, per, dapat, ...
# 4   [evaluasi, media, sosial, bawaslu, jatim, yout...
# 5   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 6   [masukpakeko, gus, yazid, ajak, masyarakat, du...
# 7   [mmmh, gus, yazid, ajak, masyarakat, dukung, b...
# 8   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 9   [dpp, partai, nasdem, juga, tunjuk, kakak, her...
# 10  [bukti, kesuksessan, perintah, selenggara, pil...
# 11  [pilkada, jalan, aman, lancar, dan, tertib, pi...
# 12  [pilkada, jalan, aman, lancar, dan, tertib, pi...
# 13  [ri, buka, peluang, sumbar, jadi, tuan, rumah,...
# 14  [halo, sahabatbawaslu, depok, desember, bawasl...
#
#                                         stopword_word
# 0                          [selamat, pagi, indonesia]
# 1   [hasil, hitung, cepat, anak, menantu, jokowi, ...
# 2                [permisi, nitip, fyp, republiksulap]
# 3   [pilkadamaut, data, positif, covid, mati, capa...
# 4   [evaluasi, media, sosial, bawaslu, jatim, yout...
# 5   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 6   [masukpakeko, gus, yazid, ajak, masyarakat, du...
# 7   [mmmh, gus, yazid, ajak, masyarakat, dukung, b...
# 8   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 9   [dpp, partai, nasdem, kakak, hermawi, taslim, ...
# 10  [bukti, kesuksessan, perintah, selenggara, pil...
# 11  [pilkada, jalan, aman, lancar, tertib, pilkada...
# 12  [pilkada, jalan, aman, lancar, tertib, pilkada...
# 13  [ri, buka, peluang, sumbar, tuan, rumah, jpi, ...
# 14  [halo, sahabatbawaslu, depok, desember, bawasl...

# %%
#joinkan content
def rejoin_words(row):
    my_list = row['stopword_word']
    joined_words = ( " ".join(my_list))
    return joined_words

trainData['processed'] = trainData.apply(rejoin_words, axis=1)

# %% [markdown]
# HASIL PREPOCESSING

# %%
pd.DataFrame(trainData)
# Out:
#     no         username                      name  \
# 0    1   kojekrapbetawi         Muhammad Amrullah
# 1    2     benar_berita       BenarNews Indonesia
# 2    3       suprabacot               scutellaria
# 3    4     lestarisarmi             Sarmi Lestari
# 4    5     bawaslujatim             Bawaslu Jatim
# 5    6    masjidrayakbm               MASJID RAYA
# 6    7   balanekangjuki  WongKebumenBisaNgapaBaen
# 7    8    penyebarkabar                Korban PHP
# 8    9          ini_net           ini.kebumen.net
# 9   10           nasdem             Partai NasDem
# 10  11   kaltimofficial           Kaltim Official
# 11  12  seputarinfoindo    Seputar Info Indonesia
# 12  13  seputarinfoindo    Seputar Info Indonesia
# 13  14   marjenrokcalva                  Rokcalva
# 14  15    bawasludepok_        Bawaslu Kota Depok
#
#                                                 tweet language Lebel  \
# 0   Selamat pagi Indonesia #pilkadacovid  https://...       in   POS
# 1   Hasil Hitung Cepat: Anak dan Menantu Jokowi Me...       in   POS
# 2   permisi... nitip dong ???? #fyp #pilkadaserent...       in   POS
# 3   pilkada2020 #pilkadacovid #pilkadamaut  Data p...       in   POS
# 4   Evaluasi Media Sosial Bawaslu Jatim, Youtube P...       in   POS
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 6   #masukpakeko  Gus Yazid Ajak Masyarakat Dukung...       in   POS
# 7   #Mmmh  Gus Yazid Ajak Masyarakat Dukung Bupati...       in   POS
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...       in   POS
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...       in   NEG
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...       in   NEG
# 11  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 12  Pilkada 2020 Berjalan Aman, Lancar dan Tertib ...       in   NEG
# 13  @KEMENPORA_RI Buka Peluang Sumbar Jadi Tuan Ru...       in   NEG
# 14  Halo #SahabatBawaslu. Depok (30 Desember 2020)...       in   NEG
#
#                                          clean_tweets  \
# 0                 Selamat pagi Indonesia pilkadacovid
# 1   Hasil Hitung Cepat Anak dan Menantu Jokowi Men...
# 2   permisi nitip dong fyp pilkadaserentak2020 PIL...
# 3   pilkada2020 pilkadacovid pilkadamaut Data per ...
# 4   Evaluasi Media Sosial Bawaslu Jatim Youtube Pa...
# 5   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 6   masukpakeko Gus Yazid Ajak Masyarakat Dukung B...
# 7   Mmmh Gus Yazid Ajak Masyarakat Dukung Bupati d...
# 8   Gus Yazid Ajak Masyarakat Dukung Bupati dan Wa...
# 9   DPP Partai NasDem juga menunjuk Kakak Hermawi ...
# 10  Bukti kesuksessan pemerintah menyelenggarakan ...
# 11  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 12  Pilkada 2020 Berjalan Aman Lancar dan Tertib P...
# 13  RI Buka Peluang Sumbar Jadi Tuan Rumah JPI Tah...
# 14  Halo SahabatBawaslu Depok 30 Desember 2020 Baw...
#
#                                       tokenizing_word  \
# 0            [Selamat, pagi, Indonesia, pilkadacovid]
# 1   [Hasil, Hitung, Cepat, Anak, dan, Menantu, Jok...
# 2   [permisi, nitip, dong, fyp, pilkadaserentak202...
# 3   [pilkada2020, pilkadacovid, pilkadamaut, Data,...
# 4   [Evaluasi, Media, Sosial, Bawaslu, Jatim, Yout...
# 5   [Gus, Yazid, Ajak, Masyarakat, Dukung, Bupati,...
# 6   [masukpakeko, Gus, Yazid, Ajak, Masyarakat, Du...
# 7   [Mmmh, Gus, Yazid, Ajak, Masyarakat, Dukung, B...
# 8   [Gus, Yazid, Ajak, Masyarakat, Dukung, Bupati,...
# 9   [DPP, Partai, NasDem, juga, menunjuk, Kakak, H...
# 10  [Bukti, kesuksessan, pemerintah, menyelenggara...
# 11  [Pilkada, 2020, Berjalan, Aman, Lancar, dan, T...
# 12  [Pilkada, 2020, Berjalan, Aman, Lancar, dan, T...
# 13  [RI, Buka, Peluang, Sumbar, Jadi, Tuan, Rumah,...
# 14  [Halo, SahabatBawaslu, Depok, 30, Desember, 20...
#
#                                         stemming_word  \
# 0            [selamat, pagi, indonesia, pilkadacovid]
# 1   [hasil, hitung, cepat, anak, dan, menantu, jok...
# 2   [permisi, nitip, dong, fyp, pilkadaserentak202...
# 3   [pilkada2020, pilkadacovid, pilkadamaut, data,...
# 4   [evaluasi, media, sosial, bawaslu, jatim, yout...
# 5   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 6   [masukpakeko, gus, yazid, ajak, masyarakat, du...
# 7   [mmmh, gus, yazid, ajak, masyarakat, dukung, b...
# 8   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 9   [dpp, partai, nasdem, juga, tunjuk, kakak, her...
# 10  [bukti, kesuksessan, perintah, selenggara, pil...
# 11  [pilkada, 2020, jalan, aman, lancar, dan, tert...
# 12  [pilkada, 2020, jalan, aman, lancar, dan, tert...
# 13  [ri, buka, peluang, sumbar, jadi, tuan, rumah,...
# 14  [halo, sahabatbawaslu, depok, 30, desember, 20...
#
#                                       panctuaton_word  \
# 0            [selamat, pagi, indonesia, pilkadacovid]
# 1   [hasil, hitung, cepat, anak, dan, menantu, jok...
# 2   [permisi, nitip, dong, fyp, republiksulap, pil...
# 3   [pilkadacovid, pilkadamaut, data, per, dapat, ...
# 4   [evaluasi, media, sosial, bawaslu, jatim, yout...
# 5   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 6   [masukpakeko, gus, yazid, ajak, masyarakat, du...
# 7   [mmmh, gus, yazid, ajak, masyarakat, dukung, b...
# 8   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 9   [dpp, partai, nasdem, juga, tunjuk, kakak, her...
# 10  [bukti, kesuksessan, perintah, selenggara, pil...
# 11  [pilkada, jalan, aman, lancar, dan, tertib, pi...
# 12  [pilkada, jalan, aman, lancar, dan, tertib, pi...
# 13  [ri, buka, peluang, sumbar, jadi, tuan, rumah,...
# 14  [halo, sahabatbawaslu, depok, desember, bawasl...
#
#                                         stopword_word  \
# 0                          [selamat, pagi, indonesia]
# 1   [hasil, hitung, cepat, anak, menantu, jokowi, ...
# 2                [permisi, nitip, fyp, republiksulap]
# 3   [pilkadamaut, data, positif, covid, mati, capa...
# 4   [evaluasi, media, sosial, bawaslu, jatim, yout...
# 5   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 6   [masukpakeko, gus, yazid, ajak, masyarakat, du...
# 7   [mmmh, gus, yazid, ajak, masyarakat, dukung, b...
# 8   [gus, yazid, ajak, masyarakat, dukung, bupati,...
# 9   [dpp, partai, nasdem, kakak, hermawi, taslim, ...
# 10  [bukti, kesuksessan, perintah, selenggara, pil...
# 11  [pilkada, jalan, aman, lancar, tertib, pilkada...
# 12  [pilkada, jalan, aman, lancar, tertib, pilkada...
# 13  [ri, buka, peluang, sumbar, tuan, rumah, jpi, ...
# 14  [halo, sahabatbawaslu, depok, desember, bawasl...
#
#                                             processed
# 0                              selamat pagi indonesia
# 1   hasil hitung cepat anak menantu jokowi tang pi...
# 2                     permisi nitip fyp republiksulap
# 3   pilkadamaut data positif covid mati capai oran...
# 4   evaluasi media sosial bawaslu jatim youtube ta...
# 5   gus yazid ajak masyarakat dukung bupati wakil ...
# 6   masukpakeko gus yazid ajak masyarakat dukung b...
# 7   mmmh gus yazid ajak masyarakat dukung bupati w...
# 8   gus yazid ajak masyarakat dukung bupati wakil ...
# 9   dpp partai nasdem kakak hermawi taslim ketua t...
# 10  bukti kesuksessan perintah selenggara pilkada ...
# 11  pilkada jalan aman lancar tertib pilkadaamanda...
# 12  pilkada jalan aman lancar tertib pilkadaamanda...
# 13  ri buka peluang sumbar tuan rumah jpi covid su...
# 14  halo sahabatbawaslu depok desember bawaslu kot...

# %%
df=pd.DataFrame(trainData)
df.to_excel('preprocesingDATA.xlsx')

# %%
# pip install translators
import translators as ts
translit=[]
for i in trainData['tweet']:
    translit.append(ts.google(i, from_language='auto', to_language='en'))
    #print(translit)
    
trainData['translit'] = translit

# %%
trainData.drop_duplicates(subset ="translit", keep = "first", inplace = True)
trainData['translit'] = trainData['translit'].astype('str') 
def get_polarity(text): 
    return TextBlob(text).sentiment.polarity
trainData['Polarity'] = trainData['translit'].apply(get_polarity)

trainData['Label']=''
trainData.loc[trainData.Polarity > 0,'Label']='POS'
trainData.loc[trainData.Polarity < 0,'Label']='NEG'

# %% [markdown]
# BOW POSITIF

# %%
#BOW POSITIF
lisbowarrayPOS = []
bowarrayPOS=[]
for indexPOS, rowPOS in trainData.iterrows():
    if rowPOS['Label'] == "POS":
        kataPOS =rowPOS["processed"]
        cleanPOS = kataPOS.split(" ")
        bowarrayPOS.append(kataPOS)
        str_listPOS = list(filter(None, cleanPOS))
        setkosongPOS = dict.fromkeys(str_listPOS,0)
        lisbowarrayPOS.append(setkosongPOS)
        #print(kataPOS)

# %%
BOWPOSNULL= pd.DataFrame(lisbowarrayPOS,index=bowarrayPOS)
BOWPOSNULL.fillna(0)
# Out:
#                                                     selamat  pagi  indonesia  \
# selamat pagi indonesia                                  0.0   0.0        0.0
# hasil hitung cepat anak menantu jokowi tang pil...      0.0   0.0        0.0
# pilkadamaut data positif covid mati capai orang...      0.0   0.0        0.0
# evaluasi media sosial bawaslu jatim youtube tar...      0.0   0.0        0.0
# pilkada jalan aman lancar tertib pilkadaamandan...      0.0   0.0        0.0
# pilkada jalan aman lancar tertib pilkadaamandan...      0.0   0.0        0.0
#
#                                                     hasil  hitung  cepat  \
# selamat pagi indonesia                                0.0     0.0    0.0
# hasil hitung cepat anak menantu jokowi tang pil...    0.0     0.0    0.0
# pilkadamaut data positif covid mati capai orang...    0.0     0.0    0.0
# evaluasi media sosial bawaslu jatim youtube tar...    0.0     0.0    0.0
# pilkada jalan aman lancar tertib pilkadaamandan...    0.0     0.0    0.0
# pilkada jalan aman lancar tertib pilkadaamandan...    0.0     0.0    0.0
#
#                                                     anak  menantu  jokowi  \
# selamat pagi indonesia                               0.0      0.0     0.0
# hasil hitung cepat anak menantu jokowi tang pil...   0.0      0.0     0.0
# pilkadamaut data positif covid mati capai orang...   0.0      0.0     0.0
# evaluasi media sosial bawaslu jatim youtube tar...   0.0      0.0     0.0
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0      0.0     0.0
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0      0.0     0.0
#
#                                                     tang  ...  \
# selamat pagi indonesia                               0.0  ...
# hasil hitung cepat anak menantu jokowi tang pil...   0.0  ...
# pilkadamaut data positif covid mati capai orang...   0.0  ...
# evaluasi media sosial bawaslu jatim youtube tar...   0.0  ...
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0  ...
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0  ...
#
#                                                     bawaslumengawasi  cegah  \
# selamat pagi indonesia                                           0.0    0.0
# hasil hitung cepat anak menantu jokowi tang pil...               0.0    0.0
# pilkadamaut data positif covid mati capai orang...               0.0    0.0
# evaluasi media sosial bawaslu jatim youtube tar...               0.0    0.0
# pilkada jalan aman lancar tertib pilkadaamandan...               0.0    0.0
# pilkada jalan aman lancar tertib pilkadaamandan...               0.0    0.0
#
#                                                     awas  tindak  jalan  aman  \
# selamat pagi indonesia                               0.0     0.0    0.0   0.0
# hasil hitung cepat anak menantu jokowi tang pil...   0.0     0.0    0.0   0.0
# pilkadamaut data positif covid mati capai orang...   0.0     0.0    0.0   0.0
# evaluasi media sosial bawaslu jatim youtube tar...   0.0     0.0    0.0   0.0
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0     0.0    0.0   0.0
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0     0.0    0.0   0.0
#
#                                                     lancar  tertib  \
# selamat pagi indonesia                                 0.0     0.0
# hasil hitung cepat anak menantu jokowi tang pil...     0.0     0.0
# pilkadamaut data positif covid mati capai orang...     0.0     0.0
# evaluasi media sosial bawaslu jatim youtube tar...     0.0     0.0
# pilkada jalan aman lancar tertib pilkadaamandan...     0.0     0.0
# pilkada jalan aman lancar tertib pilkadaamandan...     0.0     0.0
#
#                                                     pilkadaamandansehat  \
# selamat pagi indonesia                                              0.0
# hasil hitung cepat anak menantu jokowi tang pil...                  0.0
# pilkadamaut data positif covid mati capai orang...                  0.0
# evaluasi media sosial bawaslu jatim youtube tar...                  0.0
# pilkada jalan aman lancar tertib pilkadaamandan...                  0.0
# pilkada jalan aman lancar tertib pilkadaamandan...                  0.0
#
#                                                     pilkadataatiprokes
# selamat pagi indonesia                                             0.0
# hasil hitung cepat anak menantu jokowi tang pil...                 0.0
# pilkadamaut data positif covid mati capai orang...                 0.0
# evaluasi media sosial bawaslu jatim youtube tar...                 0.0
# pilkada jalan aman lancar tertib pilkadaamandan...                 0.0
# pilkada jalan aman lancar tertib pilkadaamandan...                 0.0
#
# [6 rows x 51 columns]

# %%
df=pd.DataFrame(BOWPOSNULL)
df.to_excel('setnulPOS.xlsx')

# %%
#Menghitung Kemunculan BOW Kata
from collections import Counter
bowaPOS = []
bowarrayPOS = []
setKosongPOS=[]
for index2POS, row2POS in trainData.iterrows():
    if row2POS['Label'] == "POS":
        kata2POS =row2POS["processed"]
        bowarrayPOS.append(kata2POS)
        cleanPOS = kata2POS.split(" ")
        str_listPOS = list(filter(None, cleanPOS))
        cntPOS = Counter(str_listPOS)
        setKosongPOS.append(cntPOS)
#print(setKosongNEG)

# %%
nilaiBOWPOS = pd.DataFrame(setKosongPOS, index=bowarrayPOS)
nilaiBOWPOS.fillna(0)
# Out:
#                                                     selamat  pagi  indonesia  \
# selamat pagi indonesia                                  1.0   1.0        1.0
# hasil hitung cepat anak menantu jokowi tang pil...      0.0   0.0        0.0
# pilkadamaut data positif covid mati capai orang...      0.0   0.0        0.0
# evaluasi media sosial bawaslu jatim youtube tar...      0.0   0.0        0.0
# pilkada jalan aman lancar tertib pilkadaamandan...      0.0   0.0        0.0
# pilkada jalan aman lancar tertib pilkadaamandan...      0.0   0.0        0.0
#
#                                                     hasil  hitung  cepat  \
# selamat pagi indonesia                                0.0     0.0    0.0
# hasil hitung cepat anak menantu jokowi tang pil...    1.0     1.0    1.0
# pilkadamaut data positif covid mati capai orang...    0.0     0.0    0.0
# evaluasi media sosial bawaslu jatim youtube tar...    0.0     0.0    0.0
# pilkada jalan aman lancar tertib pilkadaamandan...    0.0     0.0    0.0
# pilkada jalan aman lancar tertib pilkadaamandan...    0.0     0.0    0.0
#
#                                                     anak  menantu  jokowi  \
# selamat pagi indonesia                               0.0      0.0     0.0
# hasil hitung cepat anak menantu jokowi tang pil...   1.0      1.0     1.0
# pilkadamaut data positif covid mati capai orang...   0.0      0.0     0.0
# evaluasi media sosial bawaslu jatim youtube tar...   0.0      0.0     0.0
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0      0.0     0.0
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0      0.0     0.0
#
#                                                     tang  ...  \
# selamat pagi indonesia                               0.0  ...
# hasil hitung cepat anak menantu jokowi tang pil...   1.0  ...
# pilkadamaut data positif covid mati capai orang...   0.0  ...
# evaluasi media sosial bawaslu jatim youtube tar...   0.0  ...
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0  ...
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0  ...
#
#                                                     bawaslumengawasi  cegah  \
# selamat pagi indonesia                                           0.0    0.0
# hasil hitung cepat anak menantu jokowi tang pil...               0.0    0.0
# pilkadamaut data positif covid mati capai orang...               0.0    0.0
# evaluasi media sosial bawaslu jatim youtube tar...               1.0    1.0
# pilkada jalan aman lancar tertib pilkadaamandan...               0.0    0.0
# pilkada jalan aman lancar tertib pilkadaamandan...               0.0    0.0
#
#                                                     awas  tindak  jalan  aman  \
# selamat pagi indonesia                               0.0     0.0    0.0   0.0
# hasil hitung cepat anak menantu jokowi tang pil...   0.0     0.0    0.0   0.0
# pilkadamaut data positif covid mati capai orang...   0.0     0.0    0.0   0.0
# evaluasi media sosial bawaslu jatim youtube tar...   1.0     1.0    0.0   0.0
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0     0.0    1.0   1.0
# pilkada jalan aman lancar tertib pilkadaamandan...   0.0     0.0    1.0   1.0
#
#                                                     lancar  tertib  \
# selamat pagi indonesia                                 0.0     0.0
# hasil hitung cepat anak menantu jokowi tang pil...     0.0     0.0
# pilkadamaut data positif covid mati capai orang...     0.0     0.0
# evaluasi media sosial bawaslu jatim youtube tar...     0.0     0.0
# pilkada jalan aman lancar tertib pilkadaamandan...     1.0     1.0
# pilkada jalan aman lancar tertib pilkadaamandan...     1.0     1.0
#
#                                                     pilkadaamandansehat  \
# selamat pagi indonesia                                              0.0
# hasil hitung cepat anak menantu jokowi tang pil...                  0.0
# pilkadamaut data positif covid mati capai orang...                  0.0
# evaluasi media sosial bawaslu jatim youtube tar...                  0.0
# pilkada jalan aman lancar tertib pilkadaamandan...                  1.0
# pilkada jalan aman lancar tertib pilkadaamandan...                  1.0
#
#                                                     pilkadataatiprokes
# selamat pagi indonesia                                             0.0
# hasil hitung cepat anak menantu jokowi tang pil...                 0.0
# pilkadamaut data positif covid mati capai orang...                 0.0
# evaluasi media sosial bawaslu jatim youtube tar...                 0.0
# pilkada jalan aman lancar tertib pilkadaamandan...                 1.0
# pilkada jalan aman lancar tertib pilkadaamandan...                 1.0
#
# [6 rows x 51 columns]

# %%
df=pd.DataFrame(nilaiBOWPOS)
df.to_excel('hitungPOS.xlsx')

# %%
#Menghitung tF BOW
arrayBOW = []
arrayTweet=[]
TF = { }
for index2POS, row2POS in trainData.iterrows():
    if row2POS['Label'] == "POS":
        kata2POS =row2POS["processed"]
        arrayTweet.append(kata2POS)
        clean3 = kata2POS.split(" ")
        str_list2 = list(filter(None, clean3))
        setkosong2 = dict.fromkeys(str_list2,0)
        panjang = len(str_list2)
        for word in str_list2:
            setkosong2[word]+=1/panjang
        arrayBOW.append(setkosong2)

# %%
nilaiTFIDF = pd.DataFrame(arrayBOW, index=bowarrayPOS)
nilaiTFIDF.fillna(0)
# Out:
#                                                      selamat      pagi  \
# selamat pagi indonesia                              0.333333  0.333333
# hasil hitung cepat anak menantu jokowi tang pil...  0.000000  0.000000
# pilkadamaut data positif covid mati capai orang...  0.000000  0.000000
# evaluasi media sosial bawaslu jatim youtube tar...  0.000000  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
#
#                                                     indonesia   hasil  hitung  \
# selamat pagi indonesia                               0.333333  0.0000  0.0000
# hasil hitung cepat anak menantu jokowi tang pil...   0.000000  0.0625  0.0625
# pilkadamaut data positif covid mati capai orang...   0.000000  0.0000  0.0000
# evaluasi media sosial bawaslu jatim youtube tar...   0.000000  0.0000  0.0000
# pilkada jalan aman lancar tertib pilkadaamandan...   0.000000  0.0000  0.0000
# pilkada jalan aman lancar tertib pilkadaamandan...   0.000000  0.0000  0.0000
#
#                                                      cepat    anak  menantu  \
# selamat pagi indonesia                              0.0000  0.0000   0.0000
# hasil hitung cepat anak menantu jokowi tang pil...  0.0625  0.0625   0.0625
# pilkadamaut data positif covid mati capai orang...  0.0000  0.0000   0.0000
# evaluasi media sosial bawaslu jatim youtube tar...  0.0000  0.0000   0.0000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.0000  0.0000   0.0000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.0000  0.0000   0.0000
#
#                                                     jokowi    tang  ...  \
# selamat pagi indonesia                              0.0000  0.0000  ...
# hasil hitung cepat anak menantu jokowi tang pil...  0.0625  0.0625  ...
# pilkadamaut data positif covid mati capai orang...  0.0000  0.0000  ...
# evaluasi media sosial bawaslu jatim youtube tar...  0.0000  0.0000  ...
# pilkada jalan aman lancar tertib pilkadaamandan...  0.0000  0.0000  ...
# pilkada jalan aman lancar tertib pilkadaamandan...  0.0000  0.0000  ...
#
#                                                     bawaslumengawasi  \
# selamat pagi indonesia                                      0.000000
# hasil hitung cepat anak menantu jokowi tang pil...          0.000000
# pilkadamaut data positif covid mati capai orang...          0.000000
# evaluasi media sosial bawaslu jatim youtube tar...          0.055556
# pilkada jalan aman lancar tertib pilkadaamandan...          0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...          0.000000
#
#                                                        cegah      awas  \
# selamat pagi indonesia                              0.000000  0.000000
# hasil hitung cepat anak menantu jokowi tang pil...  0.000000  0.000000
# pilkadamaut data positif covid mati capai orang...  0.000000  0.000000
# evaluasi media sosial bawaslu jatim youtube tar...  0.055556  0.055556
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
#
#                                                       tindak     jalan  \
# selamat pagi indonesia                              0.000000  0.000000
# hasil hitung cepat anak menantu jokowi tang pil...  0.000000  0.000000
# pilkadamaut data positif covid mati capai orang...  0.000000  0.000000
# evaluasi media sosial bawaslu jatim youtube tar...  0.055556  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.142857
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.142857
#
#                                                         aman    lancar  \
# selamat pagi indonesia                              0.000000  0.000000
# hasil hitung cepat anak menantu jokowi tang pil...  0.000000  0.000000
# pilkadamaut data positif covid mati capai orang...  0.000000  0.000000
# evaluasi media sosial bawaslu jatim youtube tar...  0.000000  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.142857  0.142857
# pilkada jalan aman lancar tertib pilkadaamandan...  0.142857  0.142857
#
#                                                       tertib  \
# selamat pagi indonesia                              0.000000
# hasil hitung cepat anak menantu jokowi tang pil...  0.000000
# pilkadamaut data positif covid mati capai orang...  0.000000
# evaluasi media sosial bawaslu jatim youtube tar...  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.142857
# pilkada jalan aman lancar tertib pilkadaamandan...  0.142857
#
#                                                     pilkadaamandansehat  \
# selamat pagi indonesia                                         0.000000
# hasil hitung cepat anak menantu jokowi tang pil...             0.000000
# pilkadamaut data positif covid mati capai orang...             0.000000
# evaluasi media sosial bawaslu jatim youtube tar...             0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...             0.142857
# pilkada jalan aman lancar tertib pilkadaamandan...             0.142857
#
#                                                     pilkadataatiprokes
# selamat pagi indonesia                                        0.000000
# hasil hitung cepat anak menantu jokowi tang pil...            0.000000
# pilkadamaut data positif covid mati capai orang...            0.000000
# evaluasi media sosial bawaslu jatim youtube tar...            0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...            0.142857
# pilkada jalan aman lancar tertib pilkadaamandan...            0.142857
#
# [6 rows x 51 columns]

# %%
df=pd.DataFrame(nilaiTFIDF)
df.to_excel('hitungTFPOS.xlsx')

# %%
#mencari Nilai IDF
import math
arrayIDF = []

Bow= " ".join(arrayTweet)
Bag_Of_Word = Bow.split(" ")
str_list = list(filter(None, Bag_Of_Word))
SetBow = set(str_list)
#print(ngeset1)
SetNull = dict.fromkeys(SetBow,0)

banyak_dokumen=len(bowarrayPOS)
termglobalfreq = {}
for term in SetNull:
    count = 0
    for new in trainData['stopword_word'] :
        if term in new:
            count+=1
    if count > 0:
        termglobalfreq[term] = math.log10(banyak_dokumen/count)
    #log10(Banyak Data Dokumen Terjemahan/jumlah munculnya dokumen terjemahan terhadap trem)
arrayIDF.append(termglobalfreq)

# %%
pd.DataFrame(arrayIDF,index=["Dokumen"])
# Out:
#          indonesia     jatim    hitung     cegah    kumpul    covid  pilkada  \
# Dokumen   0.778151  0.778151  0.778151  0.778151  0.778151  0.30103      0.0
#
#          salamawas  pilkadaamandansehat      data  ...     jalan    sosial  \
# Dokumen   0.778151             0.477121  0.778151  ...  0.477121  0.778151
#
#              tang   lengkap  sahabatbawaslu    rendah     tarik     tekan  \
# Dokumen  0.778151  0.778151        0.477121  0.778151  0.778151  0.778151
#
#           youtube      anak
# Dokumen  0.778151  0.778151
#
# [1 rows x 51 columns]

# %%
df=pd.DataFrame(arrayIDF,index=["Dokumen"])
df.to_excel('hitungIDFPOS.xlsx')

# %%
#Mencarikan TFIDF 
arrayTFIDF = []
for index2POS, row2POS in trainData.iterrows():
    if row2POS['Label'] == "POS":
        kata2POS =row2POS["processed"]
        clean3 = kata2POS.split(" ")
        str_list2 = list(filter(None, clean3))
        setkosong2 = dict.fromkeys(str_list2,0)
        panjang = len(str_list2)
        for word in str_list2:
            setkosong2[word]+=1/panjang * termglobalfreq[word]
        arrayTFIDF.append(setkosong2)

# %%
hasilTFIDF = pd.DataFrame(arrayTFIDF, index=bowarrayPOS)
hasilTFIDF.fillna(0)
# Out:
#                                                      selamat      pagi  \
# selamat pagi indonesia                              0.259384  0.259384
# hasil hitung cepat anak menantu jokowi tang pil...  0.000000  0.000000
# pilkadamaut data positif covid mati capai orang...  0.000000  0.000000
# evaluasi media sosial bawaslu jatim youtube tar...  0.000000  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
#
#                                                     indonesia    hasil  \
# selamat pagi indonesia                               0.259384  0.00000
# hasil hitung cepat anak menantu jokowi tang pil...   0.000000  0.02982
# pilkadamaut data positif covid mati capai orang...   0.000000  0.00000
# evaluasi media sosial bawaslu jatim youtube tar...   0.000000  0.00000
# pilkada jalan aman lancar tertib pilkadaamandan...   0.000000  0.00000
# pilkada jalan aman lancar tertib pilkadaamandan...   0.000000  0.00000
#
#                                                       hitung     cepat  \
# selamat pagi indonesia                              0.000000  0.000000
# hasil hitung cepat anak menantu jokowi tang pil...  0.048634  0.048634
# pilkadamaut data positif covid mati capai orang...  0.000000  0.000000
# evaluasi media sosial bawaslu jatim youtube tar...  0.000000  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
#
#                                                         anak   menantu  \
# selamat pagi indonesia                              0.000000  0.000000
# hasil hitung cepat anak menantu jokowi tang pil...  0.048634  0.048634
# pilkadamaut data positif covid mati capai orang...  0.000000  0.000000
# evaluasi media sosial bawaslu jatim youtube tar...  0.000000  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
#
#                                                       jokowi      tang  ...  \
# selamat pagi indonesia                              0.000000  0.000000  ...
# hasil hitung cepat anak menantu jokowi tang pil...  0.048634  0.048634  ...
# pilkadamaut data positif covid mati capai orang...  0.000000  0.000000  ...
# evaluasi media sosial bawaslu jatim youtube tar...  0.000000  0.000000  ...
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000  ...
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000  ...
#
#                                                     bawaslumengawasi  \
# selamat pagi indonesia                                      0.000000
# hasil hitung cepat anak menantu jokowi tang pil...          0.000000
# pilkadamaut data positif covid mati capai orang...          0.000000
# evaluasi media sosial bawaslu jatim youtube tar...          0.026507
# pilkada jalan aman lancar tertib pilkadaamandan...          0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...          0.000000
#
#                                                        cegah      awas  \
# selamat pagi indonesia                              0.000000  0.000000
# hasil hitung cepat anak menantu jokowi tang pil...  0.000000  0.000000
# pilkadamaut data positif covid mati capai orang...  0.000000  0.000000
# evaluasi media sosial bawaslu jatim youtube tar...  0.043231  0.043231
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.000000
#
#                                                       tindak    jalan  \
# selamat pagi indonesia                              0.000000  0.00000
# hasil hitung cepat anak menantu jokowi tang pil...  0.000000  0.00000
# pilkadamaut data positif covid mati capai orang...  0.000000  0.00000
# evaluasi media sosial bawaslu jatim youtube tar...  0.043231  0.00000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.06816
# pilkada jalan aman lancar tertib pilkadaamandan...  0.000000  0.06816
#
#                                                        aman   lancar   tertib  \
# selamat pagi indonesia                              0.00000  0.00000  0.00000
# hasil hitung cepat anak menantu jokowi tang pil...  0.00000  0.00000  0.00000
# pilkadamaut data positif covid mati capai orang...  0.00000  0.00000  0.00000
# evaluasi media sosial bawaslu jatim youtube tar...  0.00000  0.00000  0.00000
# pilkada jalan aman lancar tertib pilkadaamandan...  0.06816  0.06816  0.06816
# pilkada jalan aman lancar tertib pilkadaamandan...  0.06816  0.06816  0.06816
#
#                                                     pilkadaamandansehat  \
# selamat pagi indonesia                                          0.00000
# hasil hitung cepat anak menantu jokowi tang pil...              0.00000
# pilkadamaut data positif covid mati capai orang...              0.00000
# evaluasi media sosial bawaslu jatim youtube tar...              0.00000
# pilkada jalan aman lancar tertib pilkadaamandan...              0.06816
# pilkada jalan aman lancar tertib pilkadaamandan...              0.06816
#
#                                                     pilkadataatiprokes
# selamat pagi indonesia                                         0.00000
# hasil hitung cepat anak menantu jokowi tang pil...             0.00000
# pilkadamaut data positif covid mati capai orang...             0.00000
# evaluasi media sosial bawaslu jatim youtube tar...             0.00000
# pilkada jalan aman lancar tertib pilkadaamandan...             0.06816
# pilkada jalan aman lancar tertib pilkadaamandan...             0.06816
#
# [6 rows x 51 columns]

# %%
df=pd.DataFrame(hasilTFIDF)
df.to_excel('hitungTFIDFPOS.xlsx')

# %%
import matplotlib.pyplot as plt
arr=np.asarray(setKosongPOS)
b = Counter(str_list)
plt.figure(figsize=(10, 8))
plt.bar(b.keys(), b.values())
# Out:
# <BarContainer object of 51 artists>

# %% [markdown]
# BOW NEGATIF

# %%
#BOW NEGATIF
lisbowarrayNEG = []
bowarrayNEG2=[]
for index, row in trainData.iterrows():
    if row['Label'] == "NEG":
        kataNEG =row["processed"]
        cleanNEG = kataNEG.split(" ")
        bowarrayNEG2.append(kataNEG)
        str_listNEG = list(filter(None, cleanNEG))
        setkosongNEG = dict.fromkeys(str_listNEG,0)
        lisbowarrayNEG.append(setkosongNEG)

# %%
BOWNEGNULL= pd.DataFrame(lisbowarrayNEG,index=bowarrayNEG2)
BOWNEGNULL.fillna(0)
# Out:
#                                                     permisi  nitip  fyp  \
# permisi nitip fyp republiksulap                         0.0    0.0  0.0
# bukti kesuksessan perintah selenggara pilkada s...      0.0    0.0  0.0
#
#                                                     republiksulap  bukti  \
# permisi nitip fyp republiksulap                               0.0    0.0
# bukti kesuksessan perintah selenggara pilkada s...            0.0    0.0
#
#                                                     kesuksessan  perintah  \
# permisi nitip fyp republiksulap                             0.0       0.0
# bukti kesuksessan perintah selenggara pilkada s...          0.0       0.0
#
#                                                     selenggara  pilkada  \
# permisi nitip fyp republiksulap                            0.0      0.0
# bukti kesuksessan perintah selenggara pilkada s...         0.0      0.0
#
#                                                     serentak  temu  klaster  \
# permisi nitip fyp republiksulap                          0.0   0.0      0.0
# bukti kesuksessan perintah selenggara pilkada s...       0.0   0.0      0.0
#
#                                                     laksana  \
# permisi nitip fyp republiksulap                         0.0
# bukti kesuksessan perintah selenggara pilkada s...      0.0
#
#                                                     fpiormasradikalislam
# permisi nitip fyp republiksulap                                      0.0
# bukti kesuksessan perintah selenggara pilkada s...                   0.0

# %%
df=pd.DataFrame(BOWNEGNULL)
df.to_excel('setnullNEG.xlsx')

# %%
#Menghitung Kemunculan BOW Kata
from collections import Counter
bowaNEG = []
bowarrayNEG = []
setKosongNEG=[]
for index2, row2 in trainData.iterrows():
    if row2['Label'] == "NEG":
        kataNEG2 =row2["processed"]
        bowarrayNEG.append(kataNEG2)
        clean22 = kataNEG2.split(" ")
        str_list12 = list(filter(None, clean22))
        cnt = Counter(str_list12)
        setKosongNEG.append(cnt)
#print(setKosongNEG)

# %%
BOWNEG = pd.DataFrame(setKosongNEG,index=bowarrayNEG)
BOWNEG.fillna(0)
# Out:
#                                                     permisi  nitip  fyp  \
# permisi nitip fyp republiksulap                         1.0    1.0  1.0
# bukti kesuksessan perintah selenggara pilkada s...      0.0    0.0  0.0
#
#                                                     republiksulap  bukti  \
# permisi nitip fyp republiksulap                               1.0    0.0
# bukti kesuksessan perintah selenggara pilkada s...            0.0    1.0
#
#                                                     kesuksessan  perintah  \
# permisi nitip fyp republiksulap                             0.0       0.0
# bukti kesuksessan perintah selenggara pilkada s...          1.0       1.0
#
#                                                     selenggara  pilkada  \
# permisi nitip fyp republiksulap                            0.0      0.0
# bukti kesuksessan perintah selenggara pilkada s...         1.0      2.0
#
#                                                     serentak  temu  klaster  \
# permisi nitip fyp republiksulap                          0.0   0.0      0.0
# bukti kesuksessan perintah selenggara pilkada s...       1.0   1.0      1.0
#
#                                                     laksana  \
# permisi nitip fyp republiksulap                         0.0
# bukti kesuksessan perintah selenggara pilkada s...      1.0
#
#                                                     fpiormasradikalislam
# permisi nitip fyp republiksulap                                      0.0
# bukti kesuksessan perintah selenggara pilkada s...                   1.0

# %%
df=pd.DataFrame(BOWNEG)
df.to_excel('hitungNEG.xlsx')

# %%
#Menghitung tF BOW
arrayBOWNEG = []
arrayTweetNEG=[]
TF = { }
for index2, row2 in trainData.iterrows():
    if row2['Label'] == "NEG":
        kataNEG2 =row2["processed"]
        arrayTweetNEG.append(kataNEG2)
        clean3 = kata2POS.split(" ")
        str_list2 = list(filter(None, clean3))
        setkosong2 = dict.fromkeys(str_list2,0)
        panjang = len(str_list2)
        for word in str_list2:
            setkosong2[word]+=1/panjang
        arrayBOWNEG.append(setkosong2)

# %%
nilaiTF = pd.DataFrame(arrayBOWNEG, index=bowarrayNEG)
nilaiTF.fillna(0)
# Out:
#                                                      pilkada     jalan  \
# permisi nitip fyp republiksulap                     0.142857  0.142857
# bukti kesuksessan perintah selenggara pilkada s...  0.142857  0.142857
#
#                                                         aman    lancar  \
# permisi nitip fyp republiksulap                     0.142857  0.142857
# bukti kesuksessan perintah selenggara pilkada s...  0.142857  0.142857
#
#                                                       tertib  \
# permisi nitip fyp republiksulap                     0.142857
# bukti kesuksessan perintah selenggara pilkada s...  0.142857
#
#                                                     pilkadaamandansehat  \
# permisi nitip fyp republiksulap                                0.142857
# bukti kesuksessan perintah selenggara pilkada s...             0.142857
#
#                                                     pilkadataatiprokes
# permisi nitip fyp republiksulap                               0.142857
# bukti kesuksessan perintah selenggara pilkada s...            0.142857

# %%
df=pd.DataFrame(nilaiTFIDF)
df.to_excel('hitungTFNEG.xlsx')

# %%
#mencari Nilai IDF
import math
arrayIDFNEG = []

Bow= " ".join(arrayTweetNEG)
Bag_Of_Word = Bow.split(" ")
str_list = list(filter(None, Bag_Of_Word))
SetBow = set(str_list)
#print(ngeset1)
SetNull = dict.fromkeys(SetBow,0)

banyak_dokumen=len(bowarrayPOS)
termglobalfreq = {}
for term in SetNull:
    count = 0
    for new in trainData['stopword_word'] :
        if term in new:
            count+=1
    if count > 0:
        termglobalfreq[term] = math.log10(banyak_dokumen/count)
    #log10(Banyak Data Dokumen Terjemahan/jumlah munculnya dokumen terjemahan terhadap trem)
arrayIDFNEG.append(termglobalfreq)

# %%
BOWNEG = pd.DataFrame(arrayIDFNEG,index=["Dokumen"])
BOWNEG.fillna(0)
# Out:
#           laksana   permisi     bukti  selenggara  kesuksessan      temu  \
# Dokumen  0.778151  0.778151  0.778151    0.477121     0.778151  0.778151
#
#          serentak  fpiormasradikalislam  republiksulap  pilkada  perintah  \
# Dokumen  0.778151              0.778151       0.778151      0.0  0.778151
#
#           klaster       fyp     nitip
# Dokumen  0.778151  0.778151  0.778151

# %%
df=pd.DataFrame(nilaiTFIDF)
df.to_excel('hitungIDFNEG.xlsx')

# %%
#Mencarikan TFIDF 
arrayTFIDFNEG = []
for index2, row2 in trainData.iterrows():
    if row2['Label'] == "NEG":
        kataNEG2 =row2["processed"]
        clean3 = kataNEG2.split(" ")
        str_list2NEG = list(filter(None, clean3))
        setkosong2NEG = dict.fromkeys(str_list2NEG,0)
        panjang = len(str_list2NEG)
        for word in str_list2NEG:
            setkosong2NEG[word]+=1/panjang * termglobalfreq[word]
        arrayTFIDFNEG.append(setkosong2NEG)

# %%
hasilTFIDFNEG = pd.DataFrame(arrayTFIDFNEG, index=bowarrayNEG)
hasilTFIDFNEG.fillna(0)
# Out:
#                                                      permisi     nitip  \
# permisi nitip fyp republiksulap                     0.194538  0.194538
# bukti kesuksessan perintah selenggara pilkada s...  0.000000  0.000000
#
#                                                          fyp  republiksulap  \
# permisi nitip fyp republiksulap                     0.194538       0.194538
# bukti kesuksessan perintah selenggara pilkada s...  0.000000       0.000000
#
#                                                        bukti  kesuksessan  \
# permisi nitip fyp republiksulap                     0.000000     0.000000
# bukti kesuksessan perintah selenggara pilkada s...  0.070741     0.070741
#
#                                                     perintah  selenggara  \
# permisi nitip fyp republiksulap                     0.000000    0.000000
# bukti kesuksessan perintah selenggara pilkada s...  0.070741    0.043375
#
#                                                     pilkada  serentak  \
# permisi nitip fyp republiksulap                         0.0  0.000000
# bukti kesuksessan perintah selenggara pilkada s...      0.0  0.070741
#
#                                                         temu   klaster  \
# permisi nitip fyp republiksulap                     0.000000  0.000000
# bukti kesuksessan perintah selenggara pilkada s...  0.070741  0.070741
#
#                                                      laksana  \
# permisi nitip fyp republiksulap                     0.000000
# bukti kesuksessan perintah selenggara pilkada s...  0.070741
#
#                                                     fpiormasradikalislam
# permisi nitip fyp republiksulap                                 0.000000
# bukti kesuksessan perintah selenggara pilkada s...              0.070741

# %%
df=pd.DataFrame(hasilTFIDFNEG)
df.to_excel('hitungTFIDFNEG.xlsx')

# %%
arr=np.asarray(setKosongNEG)
w = Counter(str_list12)
plt.figure(figsize=(10, 8))
plt.bar(w.keys(), w.values())
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# MENGHITUNG POSITIF & NEGATIF

# %%
jumlahPOS= trainData[trainData['Label'] == 'POS']['Label'].count()
jumlahNEG= trainData[trainData['Label'] == 'NEG']['Label'].count()

# %%
import matplotlib.pyplot as plt
x = np.array(["POSITIF", "NEGATIF"])
y = np.array([jumlahPOS, jumlahNEG])

plt.bar(x,y)
plt.show()

# %% [markdown]
# PROSES SVM

# %% [markdown]
# vectorizer = CountVectorizer()
# X = vectorizer.fit_transform(trainData['processed'])
# Doc_Term_Matrix = pd.DataFrame(X.toarray(),columns= vectorizer.get_feature_names())
# Doc_Term_Matrix

# %%
vectorizer = TfidfVectorizer(min_df = 5,
                             max_df = 0.8,
                             sublinear_tf = True,
                             use_idf = True)
train_vectors = vectorizer.fit_transform(trainData['processed'])
test_vectors = vectorizer.transform(testData['tweet'])

# %%
# grafik Kata positif
dataPositif = []
for i in trainData.itertuples():
    if  i.Label == "POS":
        dataPositif.extend(i.processed)

# %%
from sklearn import svm
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics
from sklearn.metrics import classification_report,accuracy_score
import six.moves.cPickle as pickle
vectorizer = TfidfVectorizer(min_df=5, max_df=0.8, 
                            sublinear_tf=True, use_idf=True)
train_features = vectorizer.fit_transform(trainData['processed'])
test_features = vectorizer.transform(testData['tweet'])

# Perform classification with SVM, kernel=linear
classifier_liblinear = svm.LinearSVC()
classifier_liblinear.fit(train_features, trainData['Label'])
prediction_liblinear = classifier_liblinear.predict(test_features)
# # Now we can use the model to predict classifications for our test features.
print(classification_report(testData['Label'], prediction_liblinear))
print("accuracy: {0}".format( accuracy_score(testData['Label'], prediction_liblinear)*100))
# Out:
#               precision    recall  f1-score   support
#
#                    0.00      0.00      0.00         0
#          NEG       0.00      0.00      0.00         5
#          NEU       0.00      0.00      0.00         8
#          POS       0.14      1.00      0.25         2
#
#     accuracy                           0.13        15
#    macro avg       0.04      0.25      0.06        15
# weighted avg       0.02      0.13      0.03        15
#
# accuracy: 13.333333333333334
# C:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
dataTRAINT=[]
for indexPOS, rowPOS in trainData.iterrows():
    if rowPOS['Label'] == "POS":
        ket = 1
    elif rowPOS['Label'] == "NEG":
        ket=0
    dataTRAINT.append(ket)

dataTRAINT
# Out:
# [1, 1, 0, 1, 1, 1, 1, 1, 1, 1, 0, 1, 1, 1, 1]

# %%
dataTEST=[]
for indexPOS, rowPOS in testData.iterrows():
    if rowPOS['Label'] == "POS":
        ket = 1
    elif rowPOS['Label'] == "NEG":
        ket=0
    dataTEST.append(ket)

dataTEST
# Out:
# [1, 1, 1, 1, 1, 1, 1, 0, 0, 1, 1, 0, 0, 0, 0]

# %%
from sklearn.metrics import confusion_matrix
actual = dataTRAINT
predicted = dataTEST

# %%
from sklearn.metrics import f1_score, precision_score, recall_score #pip install sklearn
print('Recall: {}'.format(recall_score(actual, predicted)*100))
print('Precision: {}'.format(precision_score(actual, predicted)*100))
print('F1-Score: {}'.format(f1_score(actual, predicted)*100))
# Out:
# Recall: 53.84615384615385
# Precision: 77.77777777777779
# F1-Score: 63.63636363636363
